# %% [markdown]
# # DSCI 408/508 - Team Capstone Project - Part 2
# ### By Eric Cowan, Clay Bruner, Tyler Dreiling, and Sam Risenhoover
# <br>
# The NBA is the one professional sports league where one player, one decision can create the opportunity for sustained success. In recent years, as player salaries have skyrocketed and the player empowerent era has taken hold, being able to draft well and build around those young players has become more important than ever. In the past two seasons alone, franchise altering players have been drafted and have already attained great success, both for their teams and individually. The goal of this model is to accurately predict what the statistics for any given college player would be during their rookie season in the NBA. An important note is that this will be a predictor before draft night, so the pick would not have anything to do with where the player is drafted to. The goal is to accuratle predict the numbers that a rookie player would put up in the ideal situation for them, if the role they played in college seamlessly translated to the NBA.
# <br>
# Another important note, would be that players drafted out of high school, or from overseas leagues, such as the EuroLeague, are not in this data. This data is about NCAA men's basketball players and would not be accurate for players from different leagues.

# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras import Sequential
from keras.layers import Dense

from numpy import mean
from numpy import std
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Importing the data**
#
# I will import the data that was exported in the first part of the project, this is the data that will be used in the modeling process.

# %%
#Standardized Statistics
standard = pd.read_csv('CollegeRookieStats_standardized.csv')
#PCA2, from Part 1
pca2 = pd.read_csv('CollegeRookieStats_pca2.csv')
#PCA3, from Part 1
pca3 = pd.read_csv('CollegeRookieStats_pca3.csv')
# Raw Data
stats = pd.read_csv('CollegeRookieStats.csv')

# %% [markdown]
# **Selecting the target variables**
#
# These are the target variables that we will be predicting. They are the rookie statistics for the NBA rookies. Strong rookie statistics are a good indicator of success in the NBA. Efficiency statistics, such as field goal percentage, are not included in the prediction due to the fact that efficiency is typically poor in the rookie season.

# %%
y = stats.loc[:,['NBATRB', 'NBAAST', 'NBASTL', 'NBABLK', 'NBAPTS','Year' ]]
y = y.drop(y[y['Year']==2019].index)
y = y.drop('Year', axis = 1)

# %% [markdown]
# For the standardized data, I will have to drop the columns that would not affect the output. Transposing the DataFrame will help determine what columns have no bearing on predicting future statistics.

# %%
standard.transpose()
# Out:
#                       0               1             2            3    \
# Unnamed: 0              1               2             3            4
# ID                      1               2             3            4
# Name        Kenyon Martin  Stromile Swift  Marcus Fizer  Mike Miller
# College        Cincinnati             LSU    Iowa State      Florida
# NBATeam               NJN             VAN           CHI          ORL
# DraftYear            2000            2000          2000         2000
# DraftPick               1               2             4            5
# G                0.755102        0.306122       0.62585     0.408163
# MP               0.562874        0.649701      0.838323     0.652695
# FG               0.436782        0.517241      0.747126     0.448276
# FGA              0.328125         0.40625      0.661458     0.416667
# FGP               0.61828        0.548387      0.416667     0.341398
# P2                    0.5          0.5625        0.8125       0.3625
# P2A              0.455172        0.517241      0.848276     0.337931
# P2P              0.579088        0.565684      0.402145     0.512064
# P3                      0            0.05          0.05          0.3
# P3A            0.00970874       0.0679612     0.0679612     0.339806
# P3P                  0.37        0.403333      0.486667        0.575
# FT               0.297297        0.418919      0.594595     0.418919
# FTA              0.373626        0.527473      0.659341     0.450549
# College             UCLA  Michigan State  ...  San Diego State
# NBATeam              BOS             DET  ...              CHO
# DraftYear           2000            2000  ...             2019
# DraftPick             11              14  ...               52
# G               0.387755        0.802721  ...         0.421769
# MP              0.655689        0.739521  ...         0.688623
# FG              0.494253        0.436782  ...         0.505747
# FGA             0.447917             0.5  ...         0.458333
# FGP             0.373656        0.134409  ...         0.397849
# P2                  0.55            0.35  ...            0.525
# P2A             0.593103        0.427586  ...         0.531034
# P2P             0.351206        0.214477  ...         0.439678
# P3                 0.025             0.3  ...              0.1
# P3A             0.038835        0.359223  ...         0.135922
# P3P             0.378333        0.521667  ...         0.496667
# FT              0.297297        0.351351  ...         0.364865
# FTA             0.351648        0.351648  ...         0.362637
# FTP             0.498437        0.692187  ...         0.723437
# TRB             0.504202        0.109244  ...         0.596639
# AST            0.0952381            0.75  ...         0.142857
# STL             0.321429        0.535714  ...         0.321429
# BLK             0.240741       0.0185185  ...        0.0925926
# TOV             0.392157        0.686275  ...         0.294118
# PF              0.617647        0.264706  ...         0.558824
# PTS             0.400778        0.420233  ...         0.447471
# SOS             0.843137        0.844572  ...         0.542802
# NBATRB           0.14876        0.140496  ...                0
# NBAAST         0.0114943        0.310345  ...                0
# NBASTL         0.0454545        0.272727  ...                0
# NBABLK              0.08               0  ...                0
# NBAPTS         0.0666667            0.24  ...                0
# DraftRange      0.833333        0.833333  ...         0.166667
# Pos.C                  1               0  ...                0
# Pos.PF                 0               0  ...                0
# Pos.PG                 0               1  ...                0
# Pos.SF                 0               0  ...                1
# Pos.SG                 0               0  ...                0
#
#                               627            628       629           630  \
# Unnamed: 0                    628            629       630           631
# ID                            628            629       630           631
# Name        Justin Wright-Foreman  Marial Shayok  Kyle Guy  Jaylen Hands
# College                   Hofstra     Iowa State  Virginia          UCLA
# NBATeam                       UTA            PHI       NYK           LAC
# DraftYear                    2019           2019      2019          2019
# DraftPick                      53             54        55            56
# G                        0.816327       0.197279  0.687075      0.401361
# MP                       0.694611       0.838323  0.724551      0.700599
# FG                       0.689655       0.701149  0.436782      0.402299
# FGA                      0.645833       0.645833  0.463542      0.453125
# FGP                      0.341398       0.376344  0.206989      0.142473
# P2                         0.4875          0.525       0.2          0.25
# P2A                      0.475862       0.503448  0.248276      0.310345
# P2P                      0.485255       0.520107  0.187668      0.176944
# P3                           0.55          0.525       0.6         0.425
# P3A                      0.553398       0.524272  0.543689      0.446602
# P3P                      0.643333       0.643333  0.708333      0.621667
# FT                       0.445946       0.432432  0.175676      0.310811
# FTA                      0.417582       0.362637  0.142857      0.296703
# FTP                       0.80625       0.910937  0.798438      0.729688
# TRB                      0.176471       0.344538  0.184874      0.252101
# AST                      0.214286       0.202381  0.154762      0.488095
# STL                      0.214286       0.285714  0.214286      0.392857
# BLK                      0.037037       0.037037         0      0.037037
# TOV                       0.27451       0.470588  0.156863      0.431373
# PF                       0.264706       0.411765  0.117647      0.205882
# PTS                      0.657588       0.661479  0.420233      0.404669
# SOS                      0.303682       0.858441  0.870875      0.716404
# NBATRB                          0              0         0             0
# NBAAST                          0              0         0             0
# NBASTL                          0              0         0             0
# NBABLK                          0              0         0             0
# NBAPTS                          0              0         0             0
# DraftRange               0.166667       0.166667  0.166667      0.166667
# Pos.C                           0              0         0             0
# Pos.PF                          0              0         0             0
# Pos.PG                          1              0         1             1
# Pos.SF                          0              0         0             0
# Pos.SG                          0              1         0             0
#
#                     631       632          633             634           635
# Unnamed: 0          632       633          634             635           636
# ID                  632       633          634             635           636
# Name        Jordan Bone  Miye Oni  Cam Reddish  Kevin PorterJr     Ja Morant
# College       Tennessee      Yale         Duke             USC  Murray State
# NBATeam             NOP       GSW          ATL             MIL           MEM
# DraftYear          2019      2019         2019            2019          2019
# DraftPick            57        58           10              30             2
# G              0.612245  0.557823     0.210884        0.108844      0.408163
# MP             0.634731  0.802395     0.742515         0.51497       0.91018
# FG             0.344828  0.528736     0.425287        0.333333      0.632184
# FGA               0.375  0.567708       0.5625        0.328125       0.59375
# FGP            0.182796  0.193548            0         0.30914      0.346774
# P2                0.275      0.35        0.175           0.225          0.55
# P2A            0.331034  0.386207     0.255172        0.227586      0.551724
# P2P            0.225201  0.310992    0.0536193        0.383378      0.458445
# P3                 0.25       0.5        0.625           0.325         0.325
# P3A            0.262136  0.543689     0.718447         0.31068      0.368932
# P3P            0.588333  0.593333        0.555        0.686667      0.571667
# FT             0.216216  0.364865     0.324324        0.148649      0.689189
# FTA            0.186813  0.351648     0.318681        0.208791      0.659341
# FTP            0.815625  0.753125     0.745313        0.354687      0.804688
# TRB            0.134454  0.453782     0.243697        0.268908      0.445378
# AST             0.47619  0.357143     0.190476        0.130952      0.940476
# STL            0.214286  0.285714     0.535714            0.25      0.464286
# BLK           0.0185185  0.185185     0.111111       0.0925926      0.111111
# TOV            0.254902   0.45098     0.470588        0.313725      0.686275
# PF             0.147059  0.617647          0.5        0.411765      0.294118
# PTS            0.311284   0.51751     0.459144        0.303502      0.661479
# SOS            0.875658   0.29077     0.962697        0.627451      0.231468
# NBATRB                0         0            0               0             0
# NBAAST                0         0            0               0             0
# NBASTL                0         0            0               0             0
# NBABLK                0         0            0               0             0
# NBAPTS                0         0            0               0             0
# DraftRange     0.166667  0.166667            1        0.666667             1
# Pos.C                 0         0            0               0             0
# Pos.PF                0         0            0               0             0
# Pos.PG                1         0            0               0             1
# Pos.SF                0         0            0               0             0
# Pos.SG                0         1            1               1             0
#
# [40 rows x 636 columns]

# %% [markdown]
# The columns ID, Name, NBATeam, DraftRange, Unnamed: 0, and DraftPick would not be included in the final model. College, I feel, could be a predictor of NBA success. Different Programs have different strengths and could be more likely to produce successful players. I will also remove the 2019 Draft Class, since those are the rookeis we will predict the stats for.

# %%
standard = standard.drop(['ID', 'Name', 'NBATeam', 'DraftPick', 'DraftRange', 'Unnamed: 0'], axis = 1)

# %%
def find_cat(data):
    col_list = list(data.columns)
    numList = []
    objList = []
    for col in col_list:
        if data.dtypes[col] == object:
            objList.append(col)
        elif data.dtypes[col] in [ 'int64','float64']:
            numList.append(col)
        else:
            print(f'The column {col} is niether object nor int64 nor float64')
    return [objList, numList]

# %%
cat, num = find_cat(standard)
standard[cat].nunique()
# Out:
# College    138
# dtype: int64

# %% [markdown]
# That is a large amount of different colleges, which could clog up the model and slow down the training of the neural networ. For now, I will drop the College column for sake of just looking at the player themselves. The SOS parameter, Strength of Schedule, should be an indicator of whether the team the player was on was competing or not.

# %%
standard = standard.drop('College', axis = 1)

# %%
standard.transpose()
# Out:
#                    0            1            2            3            4    \
# DraftYear  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# G             0.755102     0.306122     0.625850     0.408163     0.183673
# MP            0.562874     0.649701     0.838323     0.652695     0.676647
# FG            0.436782     0.517241     0.747126     0.448276     0.436782
# FGA           0.328125     0.406250     0.661458     0.416667     0.416667
# FGP           0.618280     0.548387     0.416667     0.341398     0.327957
# P2            0.500000     0.562500     0.812500     0.362500     0.300000
# P2A           0.455172     0.517241     0.848276     0.337931     0.268966
# P2P           0.579088     0.565684     0.402145     0.512064     0.538874
# P3            0.000000     0.050000     0.050000     0.300000     0.400000
# P3A           0.009709     0.067961     0.067961     0.339806     0.427184
# P3P           0.370000     0.403333     0.486667     0.575000     0.618333
# FT            0.297297     0.418919     0.594595     0.418919     0.297297
# FTA           0.373626     0.527473     0.659341     0.450549     0.296703
# FTP           0.446875     0.496875     0.635938     0.660937     0.690625
# TRB           0.563025     0.521008     0.554622     0.436975     0.252101
# AST           0.107143     0.047619     0.083333     0.238095     0.130952
# STL           0.357143     0.428571     0.285714     0.392857     0.321429
# BLK           0.462963     0.481481     0.166667     0.055556     0.166667
# TOV           0.254902     0.431373     0.392157     0.372549     0.215686
# PF            0.382353     0.558824     0.352941     0.352941     0.382353
# PTS           0.361868     0.455253     0.669261     0.451362     0.424125
# SOS           0.708274     0.669536     0.690100     0.728360     0.796748
# NBATRB        0.611570     0.297521     0.355372     0.330579     0.190083
# NBAAST        0.218391     0.045977     0.126437     0.195402     0.091954
# NBASTL        0.500000     0.363636     0.181818     0.272727     0.272727
# NBABLK        0.680000     0.400000     0.120000     0.080000     0.160000
# NBAPTS        0.533333     0.217778     0.422222     0.528889     0.226667
# Pos.C         0.000000     0.000000     0.000000     0.000000     0.000000
# Pos.PF        1.000000     1.000000     1.000000     0.000000     0.000000
# Pos.PG        0.000000     0.000000     0.000000     0.000000     0.000000
# Pos.SF        0.000000     0.000000     0.000000     1.000000     1.000000
# Pos.SG        0.000000     0.000000     0.000000     0.000000     0.000000
#
#                    5            6            7            8            9    \
# DraftYear  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# NBAPTS        0.000000
# Pos.C         0.000000
# Pos.PF        0.000000
# Pos.PG        1.000000
# Pos.SF        0.000000
# Pos.SG        0.000000
#
# [33 rows x 636 columns]

# %% [markdown]
# From Part 1, PCA2 is a component analysis of the following variables: FG, FGA, FG%, 2P, 2PA, 2P%, 3P, 3PA, 3P%, FT, FTA, and FT%. The PCA suggests to only use the PC1 from this and replace those variables in the standardized dataset, which is what I will do. So in the end, those 12 varaibles will be replace by the PC1 component from PCA2. PCA3 is over the remaining variables.

# %%
pc = pca2.loc[:,'PC1']
standard['PC'] = pc
X = standard.loc[:,['PC', 'G', 'MP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
                    'SOS','DraftYear','Pos.C', 'Pos.PF', 'Pos.PG', 'Pos.SF', 'Pos.SG']]
rookies_x = X.loc[X.DraftYear == 2019]
rookies_x = rookies_x.drop('DraftYear', axis = 1)
X = X.drop(X[X['DraftYear']==2019].index, axis = 0)
X = X.drop('DraftYear', axis = 1)

X.shape
# Out:
# (586, 16)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Now we have our features and our outcomes for training. The next step is to build the model. i will be using Keras and Tensorflow to construct a muli regression nueral network to preduct the 5 statistics.

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.optimizers import Adam

# %% [markdown]
# After performing several sets of parameter tuning, this is the model that we finished on. I started off with one hidden layer, but that did not provide a wide enough variance in predictions, once I added the second hidden layer and upped the initial size of the input layer, the model functioned as desired. The loss parameter, which is Mean Squared Error, is the best indicator of model accuracy from observation. The accuracy jumps up to around 95% after the first few epochs, but the loss continues to decrease the more epochs there are, and the lower the loss the better the model functions as a predictor.

# %%
# get the model
model = Sequential()
# Input layer
model.add(Dense(64, activation='relu', input_dim=16))
# Hidden Layers
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
# Output Layer
model.add(Dense(5, activation = 'linear'))
# Compile the model
model.compile(optimizer='Adam', metrics = ['acc'], loss = 'mse')

# %%
model.fit(X_train, y_train, epochs=1000, verbose=1)
# Out:
# Epoch 1/100
# 468/468 [==============================] - 0s 36us/step - loss: 0.8786 - acc: 0.9444
# Epoch 2/100
# 468/468 [==============================] - 0s 43us/step - loss: 0.8213 - acc: 0.9487
# Epoch 3/100
# 468/468 [==============================] - 0s 48us/step - loss: 0.8593 - acc: 0.9509
# Epoch 4/100
# 468/468 [==============================] - 0s 40us/step - loss: 0.8544 - acc: 0.9402
# Epoch 5/100
# 468/468 [==============================] - 0s 43us/step - loss: 0.8761 - acc: 0.9423
# Epoch 6/100
# 468/468 [==============================] - 0s 40us/step - loss: 0.9196 - acc: 0.9530
# Epoch 7/100
# 468/468 [==============================] - 0s 47us/step - loss: 0.8435 - acc: 0.9402
# Epoch 8/100
# 468/468 [==============================] - 0s 43us/step - loss: 0.9145 - acc: 0.9509
# Epoch 9/100
# 468/468 [==============================] - 0s 41us/step - loss: 0.8816 - acc: 0.9444
# Epoch 10/100
# 468/468 [==============================] - 0s 36us/step - loss: 0.8600 - acc: 0.9444
# Epoch 11/100
# 468/468 [==============================] - 0s 40us/step - loss: 0.8670 - acc: 0.9402
# Epoch 12/100
# 468/468 [==============================] - 0s 41us/step - loss: 1.0259 - acc: 0.9444
# Epoch 13/100
# 468/468 [==============================] - 0s 37us/step - loss: 0.8645 - acc: 0.9316
# Epoch 14/100
# 468/468 [==============================] - 0s 40us/step - loss: 0.8517 - acc: 0.9380
# Epoch 15/100
# 468/468 [==============================] - 0s 34us/step - loss: 0.8774 - acc: 0.9551
# Epoch 16/100
# 468/468 [==============================] - 0s 34us/step - loss: 0.8328 - acc: 0.9466
# Epoch 17/100
# 468/468 [==============================] - 0s 40us/step - loss: 0.8836 - acc: 0.9359
# Epoch 18/100
# 468/468 [==============================] - 0s 30us/step - loss: 0.
100
# 468/468 [==============================] - 0s 28us/step - loss: 0.8324 - acc: 0.9402
# Epoch 71/100
# 468/468 [==============================] - 0s 42us/step - loss: 0.9144 - acc: 0.9509
# Epoch 72/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.8273 - acc: 0.9466
# Epoch 73/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.8718 - acc: 0.9359
# Epoch 74/100
# 468/468 [==============================] - 0s 36us/step - loss: 0.7789 - acc: 0.9423
# Epoch 75/100
# 468/468 [==============================] - 0s 26us/step - loss: 0.7797 - acc: 0.9466
# Epoch 76/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.8583 - acc: 0.9509
# Epoch 77/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.7962 - acc: 0.9316
# Epoch 78/100
# 468/468 [==============================] - 0s 26us/step - loss: 0.7706 - acc: 0.9423
# Epoch 79/100
# 468/468 [==============================] - 0s 34us/step - loss: 0.7672 - acc: 0.9444
# Epoch 80/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.7836 - acc: 0.9402
# Epoch 81/100
# 468/468 [==============================] - 0s 30us/step - loss: 0.8607 - acc: 0.9487
# Epoch 82/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.7894 - acc: 0.9487
# Epoch 83/100
# 468/468 [==============================] - 0s 30us/step - loss: 0.7778 - acc: 0.9444
# Epoch 84/100
# 468/468 [==============================] - 0s 30us/step - loss: 0.8366 - acc: 0.9402
# Epoch 85/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7827 - acc: 0.9402
# Epoch 86/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7926 - acc: 0.9444
# Epoch 87/100
# 468/468 [==============================] - 0s 30us/step - loss: 0.7800 - acc: 0.9423
# Epoch 88/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.7834 - acc: 0.9466
# Epoch 89/100
# 468/468 [==============================] - 0s 26us/step - loss: 0.7886 - acc: 0.9402
# Epoch 90/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7981 - acc: 0.9444
# Epoch 91/100
# 468/468 [==============================] - 0s 27us/step - loss: 0.7808 - acc: 0.9444
# Epoch 92/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.8245 - acc: 0.9487
# Epoch 93/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7934 - acc: 0.9487
# Epoch 94/100
# 468/468 [==============================] - 0s 37us/step - loss: 0.7753 - acc: 0.9466
# Epoch 95/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7781 - acc: 0.9380
# Epoch 96/100
# 468/468 [==============================] - 0s 28us/step - loss: 0.7681 - acc: 0.9466
# Epoch 97/100
# 468/468 [==============================] - 0s 33us/step - loss: 0.7746 - acc: 0.9444
# Epoch 98/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.8294 - acc: 0.9316
# Epoch 99/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7736 - acc: 0.9530
# Epoch 100/100
# 468/468 [==============================] - 0s 32us/step - loss: 0.7988 - acc: 0.9359

# %%
y_pred_test=model.predict(X_test)

score = model.evaluate(X_test, y_test, verbose = 0)
print(score)

y_pred_train = model.predict(X_train)
# Out:
# [9.725679575386694, 0.9152542352676392]

# %%
y_pred1 = pd.DataFrame(np.round(y_pred_test,2), index = y_test.index,
                            columns = ['PRED_TRB', 'PRED_AST', 'PRED_STL', 'PRED_BLK', 'PRED_PTS'])

y_pred2 = pd.DataFrame(np.round(y_pred_train,2), index = y_train.index,
                            columns = ['PRED_TRB', 'PRED_AST', 'PRED_STL', 'PRED_BLK', 'PRED_PTS'])

test_predictions = y_pred1.join(stats.loc[:,['Name', 'G', 'School', 'Pk']])

train_predictions = y_pred2.join(stats.loc[:,['Name', 'G', 'School', 'Pk']])

test_predictions.to_csv('test_predictions.csv')
train_predictions.to_csv('train_predictions.csv')

# %% [markdown]
# Overfitting the model seems to occur once the loss metric dips below 0.7, and the best results are found around 1000 epochs.
# <br>
# Here I will use the model to predict the stats for the 2019 rookie class, which is headlined by Zion Williamson, Ja Morant, and RJ Barret.

# %%
rookies_pred = model.predict(rookies_x)

rookies_pred = pd.DataFrame(np.round(rookies_pred,2),index = rookies_x.index,
                            columns = ['PRED_TRB', 'PRED_AST', 'PRED_STL', 'PRED_BLK', 'PRED_PTS'])

# %% [markdown]
# Merging the predictions with the information about the player.

# %%
rookie_predictions = rookies_pred.join(stats.loc[:,['Name', 'G', 'School', 'Pk']]).sort_values(by = 'Pk')

rookie_predictions.to_csv('rookie_predictions.csv')

rookie_predictions.head(15)
# Out:
#       PRED_TRB  PRED_AST  PRED_STL  PRED_BLK   PRED_PTS             Name    G  \
# 586  16.190001      6.46      2.23      1.89  33.779999  Zion Williamson   33
# 635   3.330000      4.92      1.19      0.25   9.650000        Ja Morant   65
# 587   1.400000      0.99      0.38      0.23   6.470000       RJ Barrett   38
# 588   1.330000      0.57      0.24      0.16   3.740000   DeAndre Hunter   71
# 589   1.380000      1.73      0.46      0.16   5.110000   Darius Garland    5
# 590   3.440000      2.24      0.77      0.31  10.560000   Jarrett Culver   75
# 591   2.870000      3.63      0.93      0.19  12.310000       Coby White   35
# 592   7.010000      2.32      0.95      0.82  16.070000     Jaxson Hayes   32
# 593   6.630000      2.57      0.97      0.68  16.320000    Rui Hachimura  102
# 633   2.030000      1.74      0.60      0.17   8.420000      Cam Reddish   36
# 594   3.610000      0.07      0.39      0.54   4.560000  Cameron Johnson  118
# 595   3.240000      0.40      0.42      0.37   5.010000    PJ Washington   72
# 596   1.160000      0.39      0.28      0.11   4.290000      Tyler Herro   37
# 597   0.920000      0.35      0.23      0.17   3.520000   Romeo Langford   32
# 598   1.990000      0.55      0.35      0.19   3.370000      Chuma Okeke   72
#
#            School  Pk
# 586          Duke   1
# 635  Murray State   2
# 587          Duke   3
# 588      Virginia   4
# 589    Vanderbilt   5
# 590    Texas Tech   6
# 591           UNC   7
# 592         Texas   8
# 593       Gonzaga   9
# 633          Duke  10
# 594   Texas State  11
# 595      Kentucky  12
# 596      Kentucky  13
# 597       Indiana  14
# 598        Auburn  16

# %% [markdown]
# The top two players in the draft are definitely the ones you would want to pick if this predictor is the metric you will base your decision on.

# %%
rookie_pred = pd.read_csv('rookie_predictions_good.csv')
rookie_pred.drop('Unnamed: 0', axis = 1).head()
# Out:
#    PRED_TRB  PRED_AST  PRED_STL  PRED_BLK  PRED_PTS             Name   G  \
# 0      9.40      3.55      1.61      1.08     25.23  Zion Williamson  33
# 1      6.98      7.74      1.75      0.64     20.77        Ja Morant  65
# 2      4.49      3.68      1.07      0.43     17.01       RJ Barrett  38
# 3      2.52      0.73      0.50      0.25      7.25   DeAndre Hunter  71
# 4      2.94      3.96      1.04      0.23     13.07   Darius Garland   5
#
#          School  Pk
# 0          Duke   1
# 1  Murray State   2
# 2          Duke   3
# 3      Virginia   4
# 4    Vanderbilt   5
